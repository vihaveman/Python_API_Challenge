# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 578

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illizi
# Processing Record 2 of Set 1 | smolyaninovo
# Processing Record 3 of Set 1 | papatowai
# Processing Record 4 of Set 1 | margaret river
# Processing Record 5 of Set 1 | mejit
# Processing Record 6 of Set 1 | constantia
# Processing Record 7 of Set 1 | greymouth
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | anadyr
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | college
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | meppel
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | yeppoon
# Processing Record 16 of Set 1 | laojunmiao
# Processing Record 17 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | foso
# Processing Record 22 of Set 1 | fort irwin
# Processing Record 23 of Set 1 | labuan
# Processing Record 24 of Set 1 | wailua homesteads
# Processing Record 25 of Set 1 | adamstown
# Processing Record 26 of Set 1 | am djarass
# City not found. Skipping...
# Processing Record 27 of Set 1 | bilibino
# Processing Record 28 of Set 1 | port blair
# Processing Record 29 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 30 of Set 1 | selfoss
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | invercargill
# Processing Record 33 of Set 1 | keflavik
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | hun
# Processing Record 36 of Set 1 | puerto natales
# Processing Record 37 of Set 1 | ta`u
# Processing Record 38 of Set 1 | fort st. john
# Processing Record 39 of Set 1 | hadibu
# Processing Record 40 of Set 1 | paungde
# Processing Record 41 of Set 1 | crane
# Processing Record 42 of Set 1 | necochea
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | tralee
# Processing Record 45 of Set 1 | raghunathpur
# Processing Record 46 of Set 1 | viru
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | shizilu
# Processing Record 50 of Set 1 | lihue
# Processing Record 0 of Set 2 | utrik
# Processing Record 1 of Set 2 | guixi
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | west island
# Processing Record 5 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | enewetak
# Processing Record 8 of Set 2 | masterton
# Processing Record 9 of Set 2 | vorgashor
# Processing Record 10 of Set 2 | labe
# Processing Record 11 of Set 2 | edinburgh of the seven seas
# Processing Record 12 of Set 2 | ulladulla
# Processing Record 13 of Set 2 | susuman
# Processing Record 14 of Set 2 | manhumirim
# Processing Record 15 of Set 2 | lata
# Processing Record 16 of Set 2 | dudinka
# Processing Record 17 of Set 2 | lae
# Processing Record 18 of Set 2 | zeya
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | vilyuysk
# Processing Record 21 of Set 2 | kitimat
# Processing Record 22 of Set 2 | surat thani
# Processing Record 23 of Set 2 | salekhard
# Processing Record 24 of Set 2 | duba
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | haiku-pauwela
# Processing Record 27 of Set 2 | afaahiti
# Processing Record 28 of Set 2 | castillos
# Processing Record 29 of Set 2 | uturoa
# Processing Record 30 of Set 2 | tazovsky
# Processing Record 31 of Set 2 | trinidad
# Processing Record 32 of Set 2 | remire-montjoly
# Processing Record 33 of Set 2 | zhangatas
# Processing Record 34 of Set 2 | blackmans bay
# Processing Record 35 of Set 2 | boguchany
# Processing Record 36 of Set 2 | morehead city
# Processing Record 37 of Set 2 | mogocha
# Processing Record 38 of Set 2 | kayangel
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | naryn
# Processing Record 41 of Set 2 | livny
# Processing Record 42 of Set 2 | isafjordur
# Processing Record 43 of Set 2 | freetown
# Processing Record 44 of Set 2 | aasiaat
# Processing Record 45 of Set 2 | destin
# Processing Record 46 of Set 2 | novyy urengoy
# Processing Record 47 of Set 2 | sitka
# Processing Record 48 of Set 2 | ust-nera
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 0 of Set 3 | nookat
# City not found. Skipping...
# Processing Record 1 of Set 3 | itamaraca
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | ebon
# Processing Record 4 of Set 3 | alice springs
# Processing Record 5 of Set 3 | arish
# Processing Record 6 of Set 3 | don luan
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | christchurch
# Processing Record 9 of Set 3 | hammerfest
# Processing Record 10 of Set 3 | pulawy
# Processing Record 11 of Set 3 | hawaiian paradise park
# Processing Record 12 of Set 3 | san juan de miraflores
# Processing Record 13 of Set 3 | tsumeb
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | salym
# Processing Record 16 of Set 3 | harper
# Processing Record 17 of Set 3 | kolonia town
# Processing Record 18 of Set 3 | kidal
# Processing Record 19 of Set 3 | whitehorse
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | fabens
# Processing Record 22 of Set 3 | cable beach
# City not found. Skipping...
# Processing Record 23 of Set 3 | kaindy
# Processing Record 24 of Set 3 | pierre
# Processing Record 25 of Set 3 | santa marta de ortigueira
# Processing Record 26 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 27 of Set 3 | parkes
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | ponca city
# Processing Record 30 of Set 3 | mili
# Processing Record 31 of Set 3 | palmer
# Processing Record 32 of Set 3 | caleta olivia
# Processing Record 33 of Set 3 | sur
# Processing Record 34 of Set 3 | onega
# Processing Record 35 of Set 3 | tolanaro
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | phan rang-thap cham
# Processing Record 38 of Set 3 | warrnambool
# Processing Record 39 of Set 3 | hamilton
# Processing Record 40 of Set 3 | devinuwara
# City not found. Skipping...
# Processing Record 41 of Set 3 | manturovo
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | itaituba
# Processing Record 44 of Set 3 | midvagur
# Processing Record 45 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 46 of Set 3 | umm kaddadah
# Processing Record 47 of Set 3 | stanley
# Processing Record 48 of Set 3 | bukama
# Processing Record 49 of Set 3 | margate
# Processing Record 0 of Set 4 | hilo
# Processing Record 1 of Set 4 | crucecita
# Processing Record 2 of Set 4 | port mathurin
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | chipinge
# Processing Record 5 of Set 4 | torghay
# Processing Record 6 of Set 4 | kapuskasing
# Processing Record 7 of Set 4 | detva
# Processing Record 8 of Set 4 | tazacorte
# Processing Record 9 of Set 4 | sestri levante
# Processing Record 10 of Set 4 | choibalsan
# Processing Record 11 of Set 4 | sisimiut
# Processing Record 12 of Set 4 | malanje
# Processing Record 13 of Set 4 | oral
# Processing Record 14 of Set 4 | colonia
# Processing Record 15 of Set 4 | fortaleza
# Processing Record 16 of Set 4 | barakani
# Processing Record 17 of Set 4 | goroka
# Processing Record 18 of Set 4 | kattivakkam
# Processing Record 19 of Set 4 | amos
# Processing Record 20 of Set 4 | happy valley-goose bay
# Processing Record 21 of Set 4 | shenjiamen
# Processing Record 22 of Set 4 | kingston
# Processing Record 23 of Set 4 | daru
# Processing Record 24 of Set 4 | hakui
# Processing Record 25 of Set 4 | berezovyy
# Processing Record 26 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 27 of Set 4 | amahai
# Processing Record 28 of Set 4 | la serena
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | sao joao da barra
# Processing Record 31 of Set 4 | taltal
# Processing Record 32 of Set 4 | acajutla
# Processing Record 33 of Set 4 | dawei
# Processing Record 34 of Set 4 | yongchuan
# Processing Record 35 of Set 4 | kittila
# Processing Record 36 of Set 4 | strezhevoy
# Processing Record 37 of Set 4 | nagqu
# Processing Record 38 of Set 4 | villa la venta
# Processing Record 39 of Set 4 | atafu village
# Processing Record 40 of Set 4 | acarau
# Processing Record 41 of Set 4 | san rafael
# Processing Record 42 of Set 4 | nchelenge
# Processing Record 43 of Set 4 | namibe
# Processing Record 44 of Set 4 | dakhla
# Processing Record 45 of Set 4 | ballina
# Processing Record 46 of Set 4 | talnakh
# Processing Record 47 of Set 4 | benito juarez
# Processing Record 48 of Set 4 | portage la prairie
# Processing Record 49 of Set 4 | forster
# Processing Record 0 of Set 5 | mabai
# Processing Record 1 of Set 5 | matadi
# Processing Record 2 of Set 5 | usakos
# Processing Record 3 of Set 5 | mezhdurechensk
# Processing Record 4 of Set 5 | flying fish cove
# Processing Record 5 of Set 5 | zelenoborskiy
# Processing Record 6 of Set 5 | rabigh
# Processing Record 7 of Set 5 | sept-iles
# Processing Record 8 of Set 5 | namsos
# Processing Record 9 of Set 5 | tyuratam
# Processing Record 10 of Set 5 | lefkada
# Processing Record 11 of Set 5 | luoyang
# Processing Record 12 of Set 5 | borogontsy
# Processing Record 13 of Set 5 | saratamata
# City not found. Skipping...
# Processing Record 14 of Set 5 | lititz
# Processing Record 15 of Set 5 | chonchi
# Processing Record 16 of Set 5 | severo-yeniseyskiy
# Processing Record 17 of Set 5 | chodavaram
# Processing Record 18 of Set 5 | gadzhiyevo
# Processing Record 19 of Set 5 | badger
# Processing Record 20 of Set 5 | la'ie
# Processing Record 21 of Set 5 | aykhal
# Processing Record 22 of Set 5 | traverse city
# Processing Record 23 of Set 5 | iskateley
# Processing Record 24 of Set 5 | yanchep
# Processing Record 25 of Set 5 | kenai
# Processing Record 26 of Set 5 | vilyuchinsk
# Processing Record 27 of Set 5 | saipan
# Processing Record 28 of Set 5 | shatrovo
# Processing Record 29 of Set 5 | fale old settlement
# Processing Record 30 of Set 5 | palmas
# Processing Record 31 of Set 5 | mata-utu
# Processing Record 32 of Set 5 | nema
# Processing Record 33 of Set 5 | sola
# Processing Record 34 of Set 5 | arkhangel'sk
# Processing Record 35 of Set 5 | port alfred
# Processing Record 36 of Set 5 | oppdal
# Processing Record 37 of Set 5 | lawas
# Processing Record 38 of Set 5 | fukuecho
# Processing Record 39 of Set 5 | gizo
# Processing Record 40 of Set 5 | minas de marcona
# Processing Record 41 of Set 5 | juba
# Processing Record 42 of Set 5 | punta arenas
# Processing Record 43 of Set 5 | pisco
# Processing Record 44 of Set 5 | san pedro pochutla
# Processing Record 45 of Set 5 | rabo de peixe
# Processing Record 46 of Set 5 | anaconda
# Processing Record 47 of Set 5 | bayganin
# Processing Record 48 of Set 5 | seogwipo
# City not found. Skipping...
# Processing Record 49 of Set 5 | bolgatanga
# Processing Record 0 of Set 6 | nova sintra
# Processing Record 1 of Set 6 | dunaivtsi
# Processing Record 2 of Set 6 | cam ranh
# Processing Record 3 of Set 6 | inarajan village
# Processing Record 4 of Set 6 | posse
# Processing Record 5 of Set 6 | siwa oasis
# Processing Record 6 of Set 6 | galesong
# Processing Record 7 of Set 6 | queenstown
# Processing Record 8 of Set 6 | lebu
# Processing Record 9 of Set 6 | sandnessjoen
# Processing Record 10 of Set 6 | as saffaniyah
# Processing Record 11 of Set 6 | flin flon
# Processing Record 12 of Set 6 | rong kwang
# Processing Record 13 of Set 6 | ishinomaki
# Processing Record 14 of Set 6 | papao
# Processing Record 15 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 16 of Set 6 | mahanje
# Processing Record 17 of Set 6 | guateque
# Processing Record 18 of Set 6 | clearwater
# Processing Record 19 of Set 6 | felipe carrillo puerto
# Processing Record 20 of Set 6 | port augusta
# Processing Record 21 of Set 6 | takab
# Processing Record 22 of Set 6 | wagar
# Processing Record 23 of Set 6 | thenzawl
# Processing Record 24 of Set 6 | north bend
# Processing Record 25 of Set 6 | prince george
# Processing Record 26 of Set 6 | nadi
# Processing Record 27 of Set 6 | ola
# Processing Record 28 of Set 6 | xilitla
# Processing Record 29 of Set 6 | lospalos
# Processing Record 30 of Set 6 | suriapet
# Processing Record 31 of Set 6 | riviere-du-loup
# Processing Record 32 of Set 6 | rio de janeiro
# Processing Record 33 of Set 6 | chukhloma
# Processing Record 34 of Set 6 | ilulissat
# Processing Record 35 of Set 6 | port saint john's
# Processing Record 36 of Set 6 | montepuez
# Processing Record 37 of Set 6 | toliara
# Processing Record 38 of Set 6 | quelimane
# Processing Record 39 of Set 6 | aral
# Processing Record 40 of Set 6 | island harbour
# Processing Record 41 of Set 6 | igrim
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | harnai
# Processing Record 44 of Set 6 | binzhou
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | longyearbyen
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | olonkinbyen
# Processing Record 49 of Set 6 | amarillo
# Processing Record 0 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 1 of Set 7 | bel ombre
# Processing Record 2 of Set 7 | hinton
# Processing Record 3 of Set 7 | praia da vitoria
# Processing Record 4 of Set 7 | sarandi
# Processing Record 5 of Set 7 | ha tinh
# Processing Record 6 of Set 7 | inekar
# City not found. Skipping...
# Processing Record 7 of Set 7 | nemuro
# Processing Record 8 of Set 7 | tsiroanomandidy
# Processing Record 9 of Set 7 | yazd
# Processing Record 10 of Set 7 | beau vallon
# Processing Record 11 of Set 7 | preobrazheniye
# Processing Record 12 of Set 7 | sturgis
# Processing Record 13 of Set 7 | ketchikan
# Processing Record 14 of Set 7 | mermoz boabab
# Processing Record 15 of Set 7 | ciudad lazaro cardenas
# Processing Record 16 of Set 7 | al kharijah
# Processing Record 17 of Set 7 | basco
# Processing Record 18 of Set 7 | balabac
# Processing Record 19 of Set 7 | st. john's
# Processing Record 20 of Set 7 | ostersund
# Processing Record 21 of Set 7 | bandarbeyla
# Processing Record 22 of Set 7 | pailon
# Processing Record 23 of Set 7 | rawlins
# Processing Record 24 of Set 7 | ishqoshim
# Processing Record 25 of Set 7 | tromso
# Processing Record 26 of Set 7 | puerto aysen
# Processing Record 27 of Set 7 | nieuw amsterdam
# Processing Record 28 of Set 7 | makedonski brod
# Processing Record 29 of Set 7 | bereket
# Processing Record 30 of Set 7 | ed damer
# Processing Record 31 of Set 7 | vila velha
# Processing Record 32 of Set 7 | dalandzadgad
# Processing Record 33 of Set 7 | santa helena
# Processing Record 34 of Set 7 | lhasa
# Processing Record 35 of Set 7 | alaghsas
# Processing Record 36 of Set 7 | kalabo
# Processing Record 37 of Set 7 | kralendijk
# Processing Record 38 of Set 7 | qaqortoq
# Processing Record 39 of Set 7 | tofol
# Processing Record 40 of Set 7 | khadzhalmakhi
# Processing Record 41 of Set 7 | nar'yan-mar
# Processing Record 42 of Set 7 | reggane
# Processing Record 43 of Set 7 | khandyga
# Processing Record 44 of Set 7 | kayes
# Processing Record 45 of Set 7 | yuzhno-kurilsk
# Processing Record 46 of Set 7 | seversk
# Processing Record 47 of Set 7 | luau
# Processing Record 48 of Set 7 | schlusser
# Processing Record 49 of Set 7 | malvan
# Processing Record 0 of Set 8 | inari
# Processing Record 1 of Set 8 | kone
# Processing Record 2 of Set 8 | brokopondo
# Processing Record 3 of Set 8 | san patricio
# Processing Record 4 of Set 8 | mount isa
# Processing Record 5 of Set 8 | kirensk
# Processing Record 6 of Set 8 | pishva
# Processing Record 7 of Set 8 | dhidhdhoo
# Processing Record 8 of Set 8 | north battleford
# Processing Record 9 of Set 8 | coquimbo
# Processing Record 10 of Set 8 | prado
# Processing Record 11 of Set 8 | ebaye
# Processing Record 12 of Set 8 | chul'man
# Processing Record 13 of Set 8 | tura
# Processing Record 14 of Set 8 | sucre
# Processing Record 15 of Set 8 | shohimardon
# Processing Record 16 of Set 8 | pratt
# Processing Record 17 of Set 8 | floro
# Processing Record 18 of Set 8 | sao raimundo nonato
# Processing Record 19 of Set 8 | palikir - national government center
# Processing Record 20 of Set 8 | alofi
# Processing Record 21 of Set 8 | guiria
# City not found. Skipping...
# Processing Record 22 of Set 8 | chibougamau
# Processing Record 23 of Set 8 | aras-asan
# Processing Record 24 of Set 8 | bloomfield
# Processing Record 25 of Set 8 | tymovskoye
# Processing Record 26 of Set 8 | nabire
# Processing Record 27 of Set 8 | damaturu
# Processing Record 28 of Set 8 | mount gambier
# Processing Record 29 of Set 8 | tarija
# Processing Record 30 of Set 8 | lakeview
# Processing Record 31 of Set 8 | ferrandina
# Processing Record 32 of Set 8 | bodaybo
# Processing Record 33 of Set 8 | novodvinsk
# Processing Record 34 of Set 8 | general acha
# Processing Record 35 of Set 8 | muromtsevo
# Processing Record 36 of Set 8 | guane
# Processing Record 37 of Set 8 | cidreira
# Processing Record 38 of Set 8 | tamanrasset
# Processing Record 39 of Set 8 | holualoa
# Processing Record 40 of Set 8 | grand falls-windsor
# Processing Record 41 of Set 8 | udachny
# Processing Record 42 of Set 8 | howard springs
# Processing Record 43 of Set 8 | trinity beach
# Processing Record 44 of Set 8 | lubango
# Processing Record 45 of Set 8 | jurm
# Processing Record 46 of Set 8 | pedro munoz
# Processing Record 47 of Set 8 | skiathos
# Processing Record 48 of Set 8 | mirnyy
# Processing Record 49 of Set 8 | arvayheer
# Processing Record 0 of Set 9 | aligudarz
# Processing Record 1 of Set 9 | klotze
# Processing Record 2 of Set 9 | tibati
# Processing Record 3 of Set 9 | eirunepe
# Processing Record 4 of Set 9 | orneta
# Processing Record 5 of Set 9 | nadvoitsy
# Processing Record 6 of Set 9 | porto novo
# Processing Record 7 of Set 9 | zeribet el oued
# Processing Record 8 of Set 9 | qamdo
# Processing Record 9 of Set 9 | cumaral
# Processing Record 10 of Set 9 | konakovo
# Processing Record 11 of Set 9 | burela de cabo
# Processing Record 12 of Set 9 | malango
# Processing Record 13 of Set 9 | mont-dore
# Processing Record 14 of Set 9 | khovd
# Processing Record 15 of Set 9 | vadso
# Processing Record 16 of Set 9 | borgo
# Processing Record 17 of Set 9 | rosalie
# Processing Record 18 of Set 9 | mcdonough
# Processing Record 19 of Set 9 | aykol
# City not found. Skipping...
# Processing Record 20 of Set 9 | puerto baquerizo moreno
# Processing Record 21 of Set 9 | san carlos de bariloche
# Processing Record 22 of Set 9 | sao bento
# Processing Record 23 of Set 9 | inhambane
# Processing Record 24 of Set 9 | katpur
# Processing Record 25 of Set 9 | klyuchi
# Processing Record 26 of Set 9 | bacobampo
# Processing Record 27 of Set 9 | polyarnyy
# Processing Record 28 of Set 9 | oranjemund
# Processing Record 29 of Set 9 | minab
# Processing Record 30 of Set 9 | sayyan
# Processing Record 31 of Set 9 | clovis
# Processing Record 32 of Set 9 | chibuto
# Processing Record 33 of Set 9 | broome
# Processing Record 34 of Set 9 | broken hill
# Processing Record 35 of Set 9 | angaur state
# Processing Record 36 of Set 9 | tomatlan
# Processing Record 37 of Set 9 | villarrica
# Processing Record 38 of Set 9 | acapulco de juarez
# Processing Record 39 of Set 9 | axim
# Processing Record 40 of Set 9 | saint-denis
# Processing Record 41 of Set 9 | mount pearl
# Processing Record 42 of Set 9 | rongelap
# Processing Record 43 of Set 9 | luga
# Processing Record 44 of Set 9 | saint-joseph
# Processing Record 45 of Set 9 | taroa
# Processing Record 46 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 9 | tyukhtet
# Processing Record 48 of Set 9 | leava
# Processing Record 49 of Set 9 | corbin
# Processing Record 0 of Set 10 | kerikeri
# Processing Record 1 of Set 10 | conception bay south
# Processing Record 2 of Set 10 | luderitz
# Processing Record 3 of Set 10 | filadelfia
# Processing Record 4 of Set 10 | rustaq
# Processing Record 5 of Set 10 | harstad
# Processing Record 6 of Set 10 | lipnik nad becvou
# Processing Record 7 of Set 10 | guozhen
# Processing Record 8 of Set 10 | carutapera
# Processing Record 9 of Set 10 | fort bragg
# Processing Record 10 of Set 10 | liwale
# Processing Record 11 of Set 10 | usinsk
# Processing Record 12 of Set 10 | amga
# Processing Record 13 of Set 10 | laguna
# Processing Record 14 of Set 10 | huanren
# Processing Record 15 of Set 10 | bosaso
# Processing Record 16 of Set 10 | argo
# Processing Record 17 of Set 10 | newport
# Processing Record 18 of Set 10 | oriximina
# Processing Record 19 of Set 10 | dongargarh
# Processing Record 20 of Set 10 | enriquillo
# Processing Record 21 of Set 10 | wangqing
# Processing Record 22 of Set 10 | baglung
# Processing Record 23 of Set 10 | tagta
# Processing Record 24 of Set 10 | shakawe
# Processing Record 25 of Set 10 | camana
# Processing Record 26 of Set 10 | walvis bay
# Processing Record 27 of Set 10 | yigo village
# Processing Record 28 of Set 10 | ibshaway
# Processing Record 29 of Set 10 | sungailiat
# Processing Record 30 of Set 10 | buka
# Processing Record 31 of Set 10 | meadow lakes
# Processing Record 32 of Set 10 | ilhabela
# Processing Record 33 of Set 10 | longonjo
# Processing Record 34 of Set 10 | santana
# Processing Record 35 of Set 10 | riberalta
# Processing Record 36 of Set 10 | watsonville
# Processing Record 37 of Set 10 | istgah-e rah ahan-e garmsar
# Processing Record 38 of Set 10 | oyama
# Processing Record 39 of Set 10 | lorengau
# Processing Record 40 of Set 10 | dubbo
# Processing Record 41 of Set 10 | ribeira brava
# Processing Record 42 of Set 10 | tambura
# Processing Record 43 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 44 of Set 10 | isangel
# Processing Record 45 of Set 10 | nantucket
# Processing Record 46 of Set 10 | leninskoye
# Processing Record 47 of Set 10 | bang saphan
# Processing Record 48 of Set 10 | new norfolk
# Processing Record 49 of Set 10 | inda silase
# Processing Record 0 of Set 11 | the bottom
# Processing Record 1 of Set 11 | ancud
# Processing Record 2 of Set 11 | pinheiro machado
# Processing Record 3 of Set 11 | newcastle west
# Processing Record 4 of Set 11 | grand island
# Processing Record 5 of Set 11 | yerofey pavlovich
# Processing Record 6 of Set 11 | cuyo
# Processing Record 7 of Set 11 | yeed
# Processing Record 8 of Set 11 | ternate
# Processing Record 9 of Set 11 | saudarkrokur
# Processing Record 10 of Set 11 | tranqueras
# Processing Record 11 of Set 11 | las vegas
# Processing Record 12 of Set 11 | kribi
# Processing Record 13 of Set 11 | ixtapa
# Processing Record 14 of Set 11 | piacabucu
# Processing Record 15 of Set 11 | poyang
# Processing Record 16 of Set 11 | kyosai
# Processing Record 17 of Set 11 | cushing
# Processing Record 18 of Set 11 | richards bay
# Processing Record 19 of Set 11 | stornoway
# Processing Record 20 of Set 11 | desnogorsk
# Processing Record 21 of Set 11 | weno
# Processing Record 22 of Set 11 | kavaratti
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | kourou
# Processing Record 25 of Set 11 | gorontalo
# Processing Record 26 of Set 11 | andovoranto
# Processing Record 27 of Set 11 | virginia beach
# Processing Record 28 of Set 11 | paciran
# Processing Record 29 of Set 11 | sonoita
# Processing Record 30 of Set 11 | niquelandia
# Processing Record 31 of Set 11 | keila
# Processing Record 32 of Set 11 | isfara
# Processing Record 33 of Set 11 | kegeyli shahar
# Processing Record 34 of Set 11 | kupang
# Processing Record 35 of Set 11 | san jose del guaviare
# Processing Record 36 of Set 11 | newman
# Processing Record 37 of Set 11 | strugi-krasnyye
# Processing Record 38 of Set 11 | port glaud
# City not found. Skipping...
# Processing Record 39 of Set 11 | hassi messaoud
# Processing Record 40 of Set 11 | gunjur
# Processing Record 41 of Set 11 | kharp
# Processing Record 42 of Set 11 | loukhi
# Processing Record 43 of Set 11 | kirakira
# Processing Record 44 of Set 11 | port macquarie
# Processing Record 45 of Set 11 | egilsstadir
# Processing Record 46 of Set 11 | wuhai
# Processing Record 47 of Set 11 | hasaki
# Processing Record 48 of Set 11 | champerico
# Processing Record 49 of Set 11 | mar del plata
# Processing Record 0 of Set 12 | barra de santo antonio
# Processing Record 1 of Set 12 | shiyan
# Processing Record 2 of Set 12 | leh
# Processing Record 3 of Set 12 | tongliao
# Processing Record 4 of Set 12 | gueltat zemmour
# City not found. Skipping...
# Processing Record 5 of Set 12 | santa cruz de yojoa
# Processing Record 6 of Set 12 | villa gesell
# Processing Record 7 of Set 12 | manokwari
# Processing Record 8 of Set 12 | codrington
# Processing Record 9 of Set 12 | palora
# Processing Record 10 of Set 12 | saint-hilaire-de-talmont
# Processing Record 11 of Set 12 | tierp
# Processing Record 12 of Set 12 | puerto san carlos
# City not found. Skipping...
# Processing Record 13 of Set 12 | kruisfontein
# Processing Record 14 of Set 12 | nicoya
# Processing Record 15 of Set 12 | akrehamn
# Processing Record 16 of Set 12 | san andres
# Processing Record 17 of Set 12 | aguada de pasajeros
# Processing Record 18 of Set 12 | bhadasar
# Processing Record 19 of Set 12 | brady
# Processing Record 20 of Set 12 | luba
# Processing Record 21 of Set 12 | uusikaupunki
# Processing Record 22 of Set 12 | shalqar
# Processing Record 23 of Set 12 | moranbah
# Processing Record 24 of Set 12 | santa vitoria do palmar
# Processing Record 25 of Set 12 | thinadhoo
# Processing Record 26 of Set 12 | fonte boa
# Processing Record 27 of Set 12 | kuandian
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Convert Fahrenheit to Celsius and round to 2 decimal places
city_data_df['Max Temp'] = round((city_data_df['Max Temp'] - 32) * 5/9, 2)

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          illizi  26.4833    8.4667     18.41        23          70
# 1    smolyaninovo  43.2956  132.4675      8.70        75         100
# 2       papatowai -46.5619  169.4708     12.75        86         100
# 3  margaret river -33.9500  115.0667     18.39        48           9
# 4           mejit  10.2753  170.8646     26.65        78          96
#
#    Wind Speed Country        Date
# 0        4.25      DZ  1681787510
# 1        8.79      RU  1681787510
# 2        6.76      NZ  1681787510
# 3        8.25      AU  1681787510
# 4       18.01      MH  1681787510

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                illizi  26.4833    8.4667     18.41        23          70
# 1          smolyaninovo  43.2956  132.4675      8.70        75         100
# 2             papatowai -46.5619  169.4708     12.75        86         100
# 3        margaret river -33.9500  115.0667     18.39        48           9
# 4                 mejit  10.2753  170.8646     26.65        78          96
#
#          Wind Speed Country        Date
# City_ID
# 0              4.25      DZ  1681787510
# 1              8.79      RU  1681787510
# 2              6.76      NZ  1681787510
# 3              8.25      AU  1681787510
# 4             18.01      MH  1681787510

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', s=20, c='b', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature (2023-04-17)')
plt.ylabel('Max Temperature (C)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', s=20, c='g', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity (2023-04-17)')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', s=20, c='r', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness (2023-04-17)')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', s=20, c='c', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed (2023-04-17)')
plt.ylabel('Cloudiness (m/s)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def plot_linear_regression(x, y, xlabel, ylabel, title, color):
    """
    Creates a Linear Regression plot using seaborn library.
    
    x: Series or array-like object containing the data for the x-axis
    y: Series or array-like object containing the data for the y-axis
    xlabel: Label for the x-axis
    ylabel: Label for the y-axis
    title: Title of the plot
    color: Color of the plot
    """
    
    # Create a regression plot using seaborn library
    sns.regplot(x=x, y=y, color=color, line_kws={'color': 'red'})
    
    # Calculate the regression line equation and r value
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    equation = f"y = {slope:.2f}x + {intercept:.2f}"
    r_squared = f"The R Value is: {r_value**2:.2f}"
    
    # Print the equation and r value to the console
    print(equation)
    print(r_squared)
    
    # Set the axis labels and title of the plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    
    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat']> 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              illizi  26.4833    8.4667     18.41        23          70
# 1        smolyaninovo  43.2956  132.4675      8.70        75         100
# 4               mejit  10.2753  170.8646     26.65        78          96
# 5          constantia  44.1833   28.6500      6.50        87          37
# 7              bethel  41.3712  -73.4140     14.94        66         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.25      DZ  1681787510
# 1              8.79      RU  1681787510
# 4             18.01      MH  1681787510
# 5              9.24      RO  1681787452
# 7              0.00      US  1681787511

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat']< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                papatowai -46.5619  169.4708     12.75        86         100
# 3           margaret river -33.9500  115.0667     18.39        48           9
# 6                greymouth -42.4667  171.2000     13.38        97         100
# 9                grytviken -54.2811  -36.5092      2.80        90         100
# 11       port-aux-francais -49.3500   70.2167      6.49        89          98
#
#          Wind Speed Country        Date
# City_ID
# 2              6.76      NZ  1681787510
# 3              8.25      AU  1681787510
# 6              8.46      NZ  1681787511
# 9              6.46      GS  1681787511
# 11            25.79      TF  1681787511

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(x=northern_hemi_df['Lat'], y=northern_hemi_df['Max Temp'], 
                       xlabel='Latitude', ylabel='Max Temp (C)', 
                       title='Northern Hemisphere City Latitude vs. Max Temperature', color='blue')


# Show plot
plt.show()
# Out:
# y = -0.57x + 34.43
# The R Value is: 0.79

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(x=southern_hemi_df['Lat'], 
                       y=southern_hemi_df['Max Temp'], xlabel='Latitude', ylabel='Max Temp (C)', 
                       title='Southern Hemisphere City Latitude vs. Max Temperature', color='gold')



# Show plot
plt.show()
# Out:
# y = 0.34x + 28.37
# The R Value is: 0.50

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The linear regression above suggests a moderate to a high negative relationship between temperature and latitude for cities in the Northern Hemisphere. This relationship indicates a moderate to high negative relationship between humidity and latitude, where the temperature tends to decrease as latitude increases.
#
# The R-squared value of 0.77 indicates that about 77% of the variance in temperature for cities within the Northern Hemisphere can be explained by its latitude.
#
# The opposite can be said for cities in the Southern Hemisphere. The linear regression suggests a moderate positive relationship between temperature and latitude; as latitude increases, temperature also increases.
#
# The R-squared value of 0.47 indicates that about 47% of the variance in temperature for cities within the Southern Hemisphere can be explained by its latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(x=northern_hemi_df['Lat'], y=northern_hemi_df['Humidity'], 
                       xlabel='Latitude', ylabel='Humidity (%)', 
                       title='Northern Hemisphere City Latitude vs. Humidity', color='yellow')

# Show plot
plt.show()
# Out:
# y = 0.27x + 57.87
# The R Value is: 0.05

# %%
# Southern Hemisphere
plot_linear_regression(x=southern_hemi_df['Lat'], 
                       y=southern_hemi_df['Humidity'], xlabel='Latitude', ylabel='Humidity (%)', 
                       title='Southern Hemisphere City Latitude vs. Humidity', color='silver')


# Show plot
plt.show()
# Out:
# y = 0.29x + 82.93
# The R Value is: 0.06

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Both linear equations indicate a slight positive relationship between humidity and latitude for Northern and Southern Hemisphere cities.
#
# However, both relationships may be weak as the R-value of 0.01 and 0.04 indicates that only a minimal amount of the variation in humidity can be explained by latitude.  As such, latitude is not a good indicator of humidity in either hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(x=northern_hemi_df['Lat'], y=northern_hemi_df['Cloudiness'], 
                       xlabel='Latitude', ylabel='Cloudiness (%)', 
                       title='Northern Hemisphere City Latitude vs. Cloudiness', color='pink')



# Show plot
plt.show()
# Out:
# y = 0.26x + 43.76
# The R Value is: 0.02

# %%
# Southern Hemisphere
plot_linear_regression(x=southern_hemi_df['Lat'], 
                       y=southern_hemi_df['Humidity'], xlabel='Cloudiness', ylabel='Cloudiness (%)', 
                       title='Southern Hemisphere City Latitude vs. Cloudiness', color='orange')



# Show plot
plt.show()
# Out:
# y = 0.29x + 82.93
# The R Value is: 0.06

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Like in the case of humidity, there is a slight positive relationship between cloudiness and latitude for Northern and Southern Hemisphere cities, as shown in the linear equations.
#
# However, both relationships are weak, with R-values of .004, indicating that only a minimal amount of the variation in cloudiness can be explained by latitude.  As such, latitude is not a good indicator of cloudiness in either hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(x=northern_hemi_df['Lat'], y=northern_hemi_df['Wind Speed'], 
                       xlabel='Latitude', ylabel='Wind Speed (m/s)', 
                       title='Northern Hemisphere City Latitude vs. Wind Speed', color='purple')


# Show plot
plt.show()
# Out:
# y = 0.01x + 7.43
# The R Value is: 0.00

# %%
# Southern Hemisphere
plot_linear_regression(x=southern_hemi_df['Lat'], 
                       y=southern_hemi_df['Humidity'], xlabel='Wind Speed', ylabel='Wind Speed (m/s)', 
                       title='Southern Hemisphere City Latitude vs. Wind Speed', color='lime')



# Show plot
plt.show()
# Out:
# y = 0.29x + 82.93
# The R Value is: 0.06

# %% [markdown]
# **Discussion about the linear relationship:**
#
# As in humidity and cloudiness, there is a slight positive relationship between wind speed and latitude for Northern and Southern Hemisphere cities, as shown in the linear equations.
#
# However, both relationships are weak, with R-values of 0.01 and 0.04, indicating that only a minimal amount of the variation in windspeed can be explained by latitude.  As such, latitude is not a good indicator of wind speed in either hemisphere.

# %% [markdown]
# **In Summary**
#
# Latitude is only a good predictor for city temperature, which has a moderate to a high relationship with city temperatures.
#
# Latitude is not a great predictor of humidity, cloudiness or windspeed; therefore, there are other factors [not analyzed here] that may be more useful in predicting these conditions in a city.
